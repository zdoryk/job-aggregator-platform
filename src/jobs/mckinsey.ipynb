# %%
import requests
import pandas
from bs4 import BeautifulSoup
import re
import json

base_url = "https://mckapi.mckinsey.com/api/jobsearch?pageSize=1000"

# %%
pandas.DataFrame(requests.get(base_url).json().get('docs'))
# Out:
#      jobID                               title  showOnTop recordTypeName  \
# 0    15178                           Associate       True          [Job]
# 1    14376      Associate - Digital Technology       True          [Job]
# 2    14918                    Associate Intern       True          [Job]
# 3    15136                    Business Analyst       True          [Job]
# 4    15275             Business Analyst Intern       True          [Job]
# ..     ...                                 ...        ...            ...
# 394  84225      Supplier Cyber Risk Specialist      False          [Job]
# 395  54767           Sustainability Specialist      False          [Job]
# 396  80811       Tech Risk Advisory Specialist      False          [Job]
# 397  84344               Transformation Intern      False          [Job]
# 398  53793  Venture Builder - LEAP by McKinsey      False          [Job]
#
#                       jobSkillGroup                            jobSkillCode  \
# 0                   [CSS Associate]                       [ASC - Associate]
# 1                   [CSS Associate]                       [ASC - Associate]
# 2        [CSS Associate Short Term]                 [SA - Summer Associate]
# 3               [CSS Pre-Associate]                 [BA - Business Analyst]
# 4    [CSS Pre-Associate Short Term]                          [INT - Intern]
# ..                              ...                                     ...
# 394                          [CSSA]            [SCSP - Sourcing Specialist]
# 395                 [CSS Associate]                       [PS - Specialist]
# 396                          [CSSA]  [CRS - Client Service Risk Specialist]
# 397               [CSSA Short Term]      [LMI - Location Management Intern]
# 398                 [CSS Associate]             [DET1 - Digital Expert (1)]
#
#                   interest interestCategory  \
# 0               Consulting    Serve Clients
# 1               Consulting    Serve Clients
# 2               Consulting    Serve Clients
# 3               Consulting    Serve Clients
# 4               Consulting    Serve Clients
# ..                     ...              ...
# 394            Procurement   Internal roles
# 395             Consulting    Serve Clients
# 396      Risk & Compliance   Internal roles
# 397  Global Administration   Internal roles
# 398             Consulting    Serve Clients
#
#                                                 cities  \
# 0    [Abu Dhabi, Addis Ababa, Almaty, Amsterdam, As...
# 1                                [Cairo, Doha, Riyadh]
# 2    [Abu Dhabi, Addis Ababa, Amsterdam, Athens, At...
# 3    [Abu Dhabi, Addis Ababa, Athens, Atlanta, Auck...
# 4    [Abu Dhabi, Athens, Atlanta, Austin, Baku, Bar...
# ..                                                 ...
# 394  [Atlanta, Denver, Miramar, Philadelphia, Washi...
# 395  [Beijing, Hong Kong SAR, Shanghai, Shenzhen, T...
# 396  [Baku, Cairo, Casablanca, Doha, Istanbul, Joha...
# 397                                     [Johannesburg]
# 398  [Beijing, Hong Kong SAR, Shanghai, Shenzhen, T...
#
#                                              countries  ...  \
# 0    [United Arab Emirates, Ethiopia, Kazakhstan, N...  ...
# 1                         [Egypt, Qatar, Saudi Arabia]  ...
# 2    [United Arab Emirates, Ethiopia, Netherlands, ...  ...
# 3    [United Arab Emirates, Ethiopia, Greece, Unite...  ...
# 4    [United Arab Emirates, Greece, United States, ...  ...
# ..                                                 ...  ...
# 394  [United States, United States, United States, ...  ...
# 395                [China, China, China, China, China]  ...
# 396  [Azerbaijan, Egypt, Morocco, Qatar, Türkiye, S...  ...
# 397                                     [South Africa]  ...
# 398                [China, China, China, China, China]  ...
#
#                                            jobApplyURL  \
# 0    https://mckinsey.avature.net/careers/Applicati...
# 1    https://mckinsey.avature.net/careers/Applicati...
# 2    https://mckinsey.avature.net/careers/Applicati...
# 3    https://mckinsey.avature.net/careers/Applicati...
# 4    https://mckinsey.avature.net/careers/Applicati...
# ..                                                 ...
# 394  https://mckinsey.avature.net/careers/Applicati...
# 395  https://mckinsey.avature.net/careers/Applicati...
# 396  https://mckinsey.avature.net/careers/Applicati...
# 397  https://mckinsey.avature.net/careers/Applicati...
# 398  https://mckinsey.avature.net/careers/Applicati...
#
#     jobPostToLinkedInMultiplex    jobSalaryBenefits Post_to_GE  \
# 0                         [No]    $165,000-$165,000         No
# 1                          NaN                  NaN         No
# 2                         [No]  $162,500 - $162,500         No
# 3                         [No]      $90,000-$90,000         No
# 4                          NaN      $87,000-$87,000         No
# ..                         ...                  ...        ...
# 394                       [No]    $124,500-$171,200         No
# 395                        NaN                  NaN         No
# 396                        NaN                  NaN         No
# 397                       [No]                  NaN         No
# 398                        NaN                  NaN         No
#
#        compensationRange                          friendlyURL  \
# 0    $192,000 - $192,000                      associate-15178
# 1                    NaN    associate-digitaltechnology-14376
# 2                    NaN                associateintern-14918
# 3    $112,000 - $112,000                businessanalyst-15136
# 4                    NaN          businessanalystintern-15275
# ..                   ...                                  ...
# 394  $124,500 - $171,200    suppliercyberriskspecialist-84225
# 395                  NaN       sustainabilityspecialist-54767
# 396                  NaN     techriskadvisoryspecialist-80811
# 397                  NaN           transformationintern-84344
# 398                  NaN  venturebuilder-leapbymckinsey-53793
#
#                                       linkedInIndustry Einstiegslevel  \
# 0                                                  NaN            NaN
# 1    [Architecture & Planning, Banking, Information...            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 394  [Computer & Network Security, Information Tech...            NaN
# 395  [Mining & Metals, Oil & Energy, Renewables & E...            NaN
# 396                            [Management Consulting]            NaN
# 397                                                NaN            NaN
# 398  [Information Technology and Services, Internet...            NaN
#
#     shortJobSummary linkedInPostingState
# 0               NaN                  NaN
# 1               NaN                  NaN
# 2               NaN                  NaN
# 3               NaN                  NaN
# 4               NaN                  NaN
# ..              ...                  ...
# 394             NaN          New Jersey
# 395             NaN                  NaN
# 396             NaN                  NaN
# 397             NaN                  NaN
# 398             NaN                  NaN
#
# [399 rows x 33 columns]
